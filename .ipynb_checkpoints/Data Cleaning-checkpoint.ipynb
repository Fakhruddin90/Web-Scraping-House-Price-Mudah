# %%
# %%time
import pandas as pd
# Out:
# Wall time: 372 ms

# %%
data = pd.read_csv("./data/negeri-sembilan-house-for-sale-07032021-1437.csv")

# %%
data
# Out:
#                                                   Title   Types         Price  \
# 0     Single Storey Terrace House For Sell / 单层排屋出售 ...  Houses    RM 255 000
# 1                   Double storey bungalow nilai impian  Houses  RM 1 750 000
# 2     Single Storey Terrace Hse-Nusari Bayu 1, Banda...  Houses    RM 285 000
# 3     Single storey terrace house at Tmn Marida sena...  Houses    RM 280 000
# 4     50*70 ! [UMV] Single Storey Semi-D Taman Bukit...  Houses    RM 458 000
# ...                                                 ...     ...           ...
# 9319  [FREEHOLD]Double Storey Laman Orkid, Nilai Imp...  Houses    RM 455 000
# 9320                    Seremban 2 acacia semi detached  Houses    RM 988 000
# 9321  Double Storey Bungalow, Taman Lavender Heights...  Houses    RM 690 000
# 9322   Double Storey Bungalow, Rasah Kemayan Seremban 2  Houses    RM 800 000
# 9323  Double Storey Bungalow, Taman Tuanku Jaafar, S...  Houses    RM 590 000
#
# ...

# %%
data['Price'] = data['Price'].replace({"RM":"", " ":"", "permonth":"", "per month":""}, regex=True)
data['Bedrooms'] = data['Bedrooms'].replace({"Bedrooms":"", "Bedroom":"", " ":""}, regex=True)
data['Bathrooms'] = data['Bathrooms'].replace({"Bathrooms":"", "Bathroom":""," ":""}, regex=True)
data['Areas'] = data['Areas'].replace({"sq.ft.":"", " ":""}, regex=True)

# %%
data['Bedrooms'] = data['Bedrooms'].replace({"Morethan10":"10"})
data['Bedrooms'] = data['Bedrooms'].astype(int)

# %%
data.head()
# Out:
#                                                Title   Types    Price  \
# 0  Single Storey Terrace House For Sell / 单层排屋出售 ...  Houses   255000
# 1                Double storey bungalow nilai impian  Houses  1750000
# 2  Single Storey Terrace Hse-Nusari Bayu 1, Banda...  Houses   285000
# 3  Single storey terrace house at Tmn Marida sena...  Houses   280000
# 4  50*70 ! [UMV] Single Storey Semi-D Taman Bukit...  Houses   458000
#
#   Bedrooms Bathrooms Areas  Location  Release Date  \
# 0        3         2  1200  Seremban  Today, 13:50
# 1        5         5  4800     Nilai  Today, 13:50
# 2        3         2  1400  Seremban  Today, 13:41
# 3        4         2  1632  Senawang  Today, 13:40
# 4        4         2  3700  Seremban  Today, 13:40
#
#                                                  Url
# 0  https://www.mudah.my/Single+Storey+Terrace+Hou...
# 1  https://www.mudah.my/Double+storey+bungalow+ni...
# 2  https://www.mudah.my/Single+Storey+Terrace+Hse...
# ...

# %%
data['Price'] = data['Price'].replace({"permonth":""}, regex=True)
data.head()
# Out:
#                                                Title   Types    Price  \
# 0  Single Storey Terrace House For Sell / 单层排屋出售 ...  Houses   255000
# 1                Double storey bungalow nilai impian  Houses  1750000
# 2  Single Storey Terrace Hse-Nusari Bayu 1, Banda...  Houses   285000
# 3  Single storey terrace house at Tmn Marida sena...  Houses   280000
# 4  50*70 ! [UMV] Single Storey Semi-D Taman Bukit...  Houses   458000
#
#   Bedrooms Bathrooms Areas  Location  Release Date  \
# 0        3         2  1200  Seremban  Today, 13:50
# 1        5         5  4800     Nilai  Today, 13:50
# 2        3         2  1400  Seremban  Today, 13:41
# 3        4         2  1632  Senawang  Today, 13:40
# 4        4         2  3700  Seremban  Today, 13:40
#
#                                                  Url
# 0  https://www.mudah.my/Single+Storey+Terrace+Hou...
# 1  https://www.mudah.my/Double+storey+bungalow+ni...
# 2  https://www.mudah.my/Single+Storey+Terrace+Hse...
# ...

# %%
data.to_csv("./data/negeri-sembilan-house-for-sale-07032021-1437-cleaned.csv")

# %%
pd.read_csv("./data/negeri-sembilan-house-for-sale-07032021-1437-cleaned.csv")
data.head()
# Out:
#                                                Title   Types    Price  \
# 0  Single Storey Terrace House For Sell / 单层排屋出售 ...  Houses   255000
# 1                Double storey bungalow nilai impian  Houses  1750000
# 2  Single Storey Terrace Hse-Nusari Bayu 1, Banda...  Houses   285000
# 3  Single storey terrace house at Tmn Marida sena...  Houses   280000
# 4  50*70 ! [UMV] Single Storey Semi-D Taman Bukit...  Houses   458000
#
#   Bedrooms Bathrooms Areas  Location  Release Date  \
# 0        3         2  1200  Seremban  Today, 13:50
# 1        5         5  4800     Nilai  Today, 13:50
# 2        3         2  1400  Seremban  Today, 13:41
# 3        4         2  1632  Senawang  Today, 13:40
# 4        4         2  3700  Seremban  Today, 13:40
#
#                                                  Url
# 0  https://www.mudah.my/Single+Storey+Terrace+Hou...
# 1  https://www.mudah.my/Double+storey+bungalow+ni...
# 2  https://www.mudah.my/Single+Storey+Terrace+Hse...
# ...

# %%
data.dtypes
# Out:
# Title           object
# Types           object
# Price           object
# Bedrooms        object
# Bathrooms       object
# Areas           object
# Location        object
# Release Date    object
# Url             object
# dtype: object

# %%
data['Price'] = data['Price'].astype(int)
data['Bedrooms'] = data['Bedrooms'].astype(int)
data['Bathrooms'] = data['Bathrooms'].astype(int)
data['Areas'] = data['Areas'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-81ebac12e765> in <module>
#       1 data['Price'] = data['Price'].astype(int)
# ----> 2 data['Bedrooms'] = data['Bedrooms'].astype(int)
#       3 data['Bathrooms'] = data['Bathrooms'].astype(int)
#       4 data['Areas'] = data['Areas'].astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
# ...

# %%
data.dtypes
# Out:
# Title           object
# Price            int32
# Bedrooms         int32
# Bathrooms        int32
# Areas            int32
# Location        object
# Release Date    object
# Url             object
# dtype: object

# %%
data.describe()
# Out:
#                Price    Bedrooms   Bathrooms       Areas
# count     766.000000  766.000000  766.000000   766.00000
# mean     2271.661880    2.844648    2.044386  1013.83812
# std     14816.815722    0.594653    0.474846   250.19538
# min       250.000000    1.000000    1.000000    20.00000
# 25%      1200.000000    3.000000    2.000000   801.25000
# 50%      1400.000000    3.000000    2.000000  1000.00000
# 75%      1800.000000    3.000000    2.000000  1200.00000
# max    320000.000000    4.000000    9.000000  1900.00000

# %%
data['Per-Sqft'] = data['Price'] / data['Areas']

# %%
data.dtypes
# Out:
# Title            object
# Price             int32
# Bedrooms          int32
# Bathrooms         int32
# Areas             int32
# Location         object
# Release Date     object
# Url              object
# Per-Sqft        float64
# dtype: object

# %%
data.head()
# Out:
#                                                Title  Price  Bedrooms  \
# 0  Saujana Aster Condo Presint 11 Putrajaya house...   1200         4
# 1  Putrajaya Saujana Aster/Presint 11/Party Furni...   1550         4
# 2                Puteri Palma Condominium, Putrajaya   2000         3
# 3  FOR RENT ||FULLY FURNISHED|| Palma Condominium...   1600         3
# 4                Puteri Palma Condominium, Putrajaya   2600         3
#
#    Bathrooms  Areas   Location      Release Date  \
# 0          2   1043  Putrajaya  Yesterday, 22:49
# 1          2   1146  Putrajaya  Yesterday, 22:35
# 2          3   1400  Putrajaya  Yesterday, 22:30
# 3          2   1000  Putrajaya  Yesterday, 22:30
# 4          3   1600  Putrajaya  Yesterday, 22:22
#
#                                                  Url  Per-Sqft
# 0  https://www.mudah.my/Saujana+Aster+Condo+Presi...  1.150527
# 1  https://www.mudah.my/Putrajaya+Saujana+Aster+P...  1.352531
# ...

# %%
data.describe()
# Out:
#                Price    Bedrooms   Bathrooms       Areas    Per-Sqft
# count     766.000000  766.000000  766.000000   766.00000  766.000000
# mean     2271.661880    2.844648    2.044386  1013.83812    2.491978
# std     14816.815722    0.594653    0.474846   250.19538   17.868621
# min       250.000000    1.000000    1.000000    20.00000    0.208333
# 25%      1200.000000    3.000000    2.000000   801.25000    1.218230
# 50%      1400.000000    3.000000    2.000000  1000.00000    1.532567
# 75%      1800.000000    3.000000    2.000000  1200.00000    1.810865
# max    320000.000000    4.000000    9.000000  1900.00000  355.555556

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         766 non-null    object
#  1   Price         766 non-null    int32
#  2   Bedrooms      766 non-null    int32
#  3   Bathrooms     766 non-null    int32
#  4   Areas         766 non-null    int32
#  5   Location      766 non-null    object
#  6   Release Date  766 non-null    object
#  7   Url           766 non-null    object
#  8   Per-Sqft      766 non-null    float64
# dtypes: float64(1), int32(4), object(4)
# memory usage: 42.0+ KB

# %%
data['Price'].max()
# Out:
# 320000

# %%
data['Price'].min()
# Out:
# 250

# %%
data.min()
# Out:
# Title           (100% rental refund) Putrajaya new condo rent ...
# Price                                                         250
# Bedrooms                                                        1
# Bathrooms                                                       1
# Areas                                                          20
# Location                                                Putrajaya
# Release Date                                        Dec 12, 06:10
# Url             https://www.mudah.my/+100+rental+refund+Putraj...
# Per-Sqft                                                 0.208333
# dtype: object

# %%
data.max()
# Out:
# Title                                  П�� Apartment untuk disewa
# Price                                                      320000
# Bedrooms                                                        4
# Bathrooms                                                       9
# Areas                                                        1900
# Location                                                Putrajaya
# Release Date                                     Yesterday, 22:49
# Url             https://www.mudah.my/Well+kept+whole+unit+Cone...
# Per-Sqft                                                  355.556
# dtype: object

# %%
data.to_csv("./data/putrajaya-apartments-rent-13022021-0309-cleaned.csv", index=False)

# %%
pd.read_csv("./data/putrajaya-apartments-rent-13022021-0309-cleaned.csv")
data.head()
# Out:
#                                                Title  Price  Bedrooms  \
# 0  Saujana Aster Condo Presint 11 Putrajaya house...   1200         4
# 1  Putrajaya Saujana Aster/Presint 11/Party Furni...   1550         4
# 2                Puteri Palma Condominium, Putrajaya   2000         3
# 3  FOR RENT ||FULLY FURNISHED|| Palma Condominium...   1600         3
# 4                Puteri Palma Condominium, Putrajaya   2600         3
#
#    Bathrooms  Areas   Location      Release Date  \
# 0          2   1043  Putrajaya  Yesterday, 22:49
# 1          2   1146  Putrajaya  Yesterday, 22:35
# 2          3   1400  Putrajaya  Yesterday, 22:30
# 3          2   1000  Putrajaya  Yesterday, 22:30
# 4          3   1600  Putrajaya  Yesterday, 22:22
#
#                                                  Url  Per-Sqft
# 0  https://www.mudah.my/Saujana+Aster+Condo+Presi...  1.150527
# 1  https://www.mudah.my/Putrajaya+Saujana+Aster+P...  1.352531
# ...
